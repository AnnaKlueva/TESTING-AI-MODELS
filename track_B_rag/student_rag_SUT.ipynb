# %% [markdown]
# # Демо RAG-система — System Under Test (трек B, для студентів)
#
# Ти — **QA-команда**. DS-команда передала release candidate RAG-асистента Acme Cloud (EN + UA).
# Протестуй його проти `release_notes_rag.md`.
#
# Усе локально на безкоштовному Colab: ембединги e5 (multilingual) + генератор Qwen 2.5. **Без API-ключів.**
#
# > ⚠️ Доброчесність: працюй через `rag.ask()` / `rag.retrieve()`. Дефекти шукай сам.

# %%
# !pip -q install transformers torch accelerate bitsandbytes langchain-chroma langchain-huggingface langchain-text-splitters sentence-transformers

# %%
from rag_sut import RagSUT

rag = RagSUT()
print(rag.ask('How much does the Pro plan cost?'))

# %%
import json
gold = json.load(open('rag_eval_starter.json', encoding='utf-8'))
print(len(gold['cases']), 'starter cases (extend to 30+)')
print(rag.retrieve('How much storage does the Free plan include?'))

# %% [markdown]
# ## Контракт (з release_notes_rag.md)
# (1) Коректність за базою знань; (2) заземлення на джерела; (3) безпечна відмова на питання поза базою;
# (4) узгодженість EN/UA.
#
# ## Твоя робота (далі — твій код, у `tests/`)
# - **Retrieval-метрики БЕЗ API** (зан. 13): Recall@K / MRR / Hit Rate — порівнюй `sources`
#   з `gold_doc_ids` зі стартового набору (розшир до 30+);
# - **faithfulness / достовірність** (зан. 13–14): чи відповідь ґрунтується на знайденому;
# - **негативні кейси** (зан. 14): питання поза базою (напр. Enterprise) → очікуй safe refusal;
# - **EN/UA узгодженість** (зан. 11): еквівалентні питання двома мовами;
# - знахідки → `reports/results.md` (severity + root cause).
#
# > Усе оцінювання — безкоштовне: retrieval-метрики не потребують моделі взагалі;
# > для judge — лише локальна модель.
